# %%
import requests
from bs4 import BeautifulSoup
import time
from IPython.display import HTML

#build the url link with searching data scientist job in Toronto
URL_1 = 'https://ca.indeed.com/jobs?q=data+scientist&l=Toronto&start'
HTML(URL_1)
job_counter = 0


def get_all_search_pages(URL_1):

    # get the HTML of the first search results page
    r = requests.get(URL_1)
    content = r.text

    # make a soup out of the first page of search results
    soup_1 = BeautifulSoup(content, 'lxml')

    # extract the number of search results
    num_results_str = soup_1.find('div', {'id': 'searchCount'}).text
    # parse the string and extract the total number (4th element), replace comma with an empty space, convert to int
    total_results = int(num_results_str.split()[3].replace(',', ''))

    # add the common part between all search pages
    next_pages_links = "https://www.indeed.ca" + soup_1.find('div', {'class': 'pagination'}).find('a').get('href')[:-2]

    print(next_pages_links)

    # create empty list to store URLs of all search results pages
    List_of_all_URLs = []

    # add the first page to the 'List_of_all_URLs'
    List_of_all_URLs.append(next_pages_links)

    # add different starting positions for subsequent search results pages to 'List_of_all_URLs'
    for start_position in range(20, total_results, 20):
        List_of_all_URLs.append(next_pages_links + str(start_position))

    return List_of_all_URLs, total_results


List_of_all_URLs, total_results = get_all_search_pages(URL_1)
print("\n{0} links with search results pages generated and saved to 'List_of_all_URLs'.".format(len(List_of_all_URLs)) +
      " Search returned a total of {0} results\n".format(total_results))
print(List_of_all_URLs)

scraping_results_dict = {}  # this is a global dict used by 'scrape_job_info' to store scraping results to be parsed later


def scrape_job_info(job_search_results):

    global scraping_results_dict  # dict used to store results of scraping

    # loop over all <div> tags supplied by the function 'scrape_job_links_and_info'
    for x in job_search_results:
        # extract the individual job posting link from a <div> tag
        # res = x.find('a')['href']
        global job_counter
        title = x.find('div',{"class":"title"})
        job_href = title.find('a')['href']
        job_title = title.find('a')['title']
        job_link = "https://www.indeed.ca" + job_href
        job_counter+=1
        print("---------------------------------------------------------------------------------")
        print("==>Job #",job_counter,": ",job_title)
        print("==>Link:",job_link)

        # get the HTML code from the job posting page and save it as text to 'scraping_results_dict'
        # link to the job posting is used as a key and HTML code of the job posting as a value
        job_html = requests.get(job_link)
        scraping_results_dict[job_link] = job_html.text

        # sleep for 0.5 second, to avoid too many requests to the indeed.ca server
        time.sleep(0.5)


def scrape_job_links_and_info(List_of_all_URLs):

    # loop over all pages in 'List_of_all_URLs' to extract links to each job posting
    for page_url in List_of_all_URLs:
        # get the HTML of the search results page
        page = requests.get(page_url)
        content = page.text
        # make a soup out of the HTML
        soup = BeautifulSoup(content, 'lxml')

        # find all <div> tags containing each job posting links and feed them to the function 'scrape_job_info'
        results = soup.find_all('div', {'class': 'jobsearch-SerpJobCard unifiedRow row result'})
        scrape_job_info(results)

    print("Done!")


# run function 'scrape_job_links_and_info' to scrape every job posting from search results pages in 'List_of_all_URLs'
print("==========================================")
print("Soup Master on duty!===>")
print("==========================================\n")
scrape_job_links_and_info(List_of_all_URLs)
print(len(scraping_results_dict),"job postings have been scraped and saved to 'scraping_results_dict'.")
# Out:
# https://www.indeed.ca/jobs?q=data+scientist&l=Toronto&start=
#
# 13 links with search results pages generated and saved to 'List_of_all_URLs'. Search returned a total of 251 results
#
# ['https://www.indeed.ca/jobs?q=data+scientist&l=Toronto&start=', 'https://www.indeed.ca/jobs?q=data+scientist&l=Toronto&start=20', 'https://www.indeed.ca/jobs?q=data+scientist&l=Toronto&start=40', 'https://www.indeed.ca/jobs?q=data+scientist&l=Toronto&start=60', 'https://www.indeed.ca/jobs?q=data+scientist&l=Toronto&start=80', 'https://www.indeed.ca/jobs?q=data+scientist&l=Toronto&start=100', 'https://www.indeed.ca/jobs?q=data+scientist&l=Toronto&start=120', 'https://www.indeed.ca/jobs?q=data+scientist&l=Toronto&start=140', 'https://www.indeed.ca/jobs?q=data+scientist&l=Toronto&start=160', 'https://www.indeed.ca/jobs?q=data+scientist&l=Toronto&start=180', 'https://www.indeed.ca/jobs?q=data+scientist&l=Toronto&start=200', 'https://www.indeed.ca/jobs?q=data+scientist&l=Toronto&start=220', 'https://www.indeed.ca/jobs?q=data+scientist&l=Toronto&start=240']
# ==========================================
# Soup Master on duty!===>
# ==========================================
#
# ---------------------------------------------------------------------------------
# ==>Job # 1 :  Senior Data Scientist - Private Wealth
# ==>Link: https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYlbfkN0DPvDrY7fOi7IBjGen6Dx7RXxfTf3xqH9cPvuoqrlxtCEWGirnFmPeDqLmC0lmmv52T0OQy3uAgY4IMj43A9fADUrAakpKkjAiscrJrl6RaWxm5vlVTfU45ySXxPpObUjZLPoBJJshMgeq5lO-8um2MuSQRGAyfP5MVhjY4w1Hb3EurpVfua2TqwQBQtg-XeBEMuiv2pxEY6jHIoEamKwhCeOKTmxdup98JPb_f5iw-Pdrm2LotfwnSlEU0sGQvlXk_qXkAOaWRUDltGfskedKihCCGyb9dbbwE6ymsYd7YBd2M_Bm8KKeEx-hNZ4Ew_NF1yOG4N7eHWfuAdD3VWZTx7eQ1H7wKZwvHklhyqzUCCOJHZLpqvEIxW_T59ae3ydx41Mfo9eLxXKMXrDwdtygHR-bqGja_QQGSfgyxP2C3dZkmTX23D319gw2IqaqjzopRrriCDCbdOO58fBZi7sm2Eb-KgBXwTGiF0gmkdPQvgjanBtZ1C7_tEBc9CPU8jdvKFxZAD_ZGN68qnNiqPXzjd4lmqkYheoUnTZqBpnLoeL7aRChA2SP_wTc43zappT67Poih3EGARg==&p=0&fvj=0&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 2 :  Data Scientist - Price Point – Start-up company
# ==>Link: https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYlbfkN0BJik0eOC2RiRcwALxZHhvolY0CiBGpIrD3jqHmT6hgcj9GGUq3nwzxcDRn3ID9hoVNHpFJfiMZVEii0Cjbtagb3mhNDEo_oIHpFMg9rCWYzYfQN4HIi5Iz2oA57hgnhTPzzOvyQ_a7LX3zRK22bHJRRSaN0PAPBBB3IrcOYUTwERDLLiyrZe1rusITCDvIEt0RXqu0Ns6FRbphOiUbLsWDce6NNVMDUoBywWSFlWhSl2qYo_NjfUf4dcf4kXw0YSvadzy9Hw_aHFQba2av6Ol0QS-R5Vy5I8zZZtFfztAZG6pIgjMiS613MWNTEIACW0hhp_mPcEiMjWz1WDlJx0gS7aLSpT3K6lcGzo_Kf0_fqRx44i-dED6QXtNFzo_d1MjxTnCMqz5g2Ag58qPHPiyxfbg6otZvYe8-754DOSy_Gc6dyz7BiXi_MeYu1k6cLf9OHRQrYM9EFU4fuq64kmI6gI60jt09GQNC3p0FS8RGzA8aVMfpQO9bgGYAaYu55ztskm6XelqRIquLUj9aWgbhAiwkw7DAVNposSMshBvHTeHt_t18aoO-2lEUDSDb-uIsFuIGE0ex4w==&p=1&fvj=0&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 3 :  Sr. Data Engineer – Big Data
# ==>Link: https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYlbfkN0BlgGQq54RhTRbtNOtgf4q8ADJ3rNd1t7LC5bhoOEgeTJsUKQgehXcdqAKPOCuOlprjkGkz7OP3XVrPOTDcIgNPNUqAPKroP-1rENzkyHGcnm83XfjvXvpWPT0bTvC0DtrpTTWh3g4xecMLNVsO9eiYc8LO4QCh21Kdq1RnOBItotxGlqEEsgHWQ4iWgQarrpreOI_QDPhMemYW3u-49izX_cZlfYRgRvnzorgPMZxWiJRYN7pm02uaNQxbk2_NgBwskX6ctUcGO6LKbuRMstsO4SnrekK-psS2mSgFQV6IyYZkkOSHC1aIsB8IfCyv5eNkkyYNLlgaQjaxZdCE8msqhvj1XHyBFwOB-NW0u90CHg5FU78h68JfAkBG_8wBJ8EpNl0frb4LWOhUTvEs9uw5qQwf7YlexFPe18RmNoOMzR_DKgtWuJy9IrEJ-1J5oUDREVUqiroqPEI4C-WgLmDwPVBFe5-JUxBmPmioMLTVbJ2Z7USRoTB3ZW2l4T32hVbdqYcymxKmxx7DpoOBVPf1MKAjRejTvOlvV23EwJ2QsyTRjglWCOnmdMlYP9rQkkX8QgV8RRo42sLd3BJsTes14OK0v6hUzZBPAoKqasRoEWo0S_pntRBP&p=2&fvj=0&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 4 :  Python Data Scientist - Research and Engineering
# ==>Link: https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYlbfkN0BFUzwZI7hB6sL3-1CSRuneG5TadXY2WMHKQsf1P6r6k45m7TN6EVbfDXe_axt3BS7b6n5egkEfAym44vnFG7hMQfQR9CMQJY7kizhXvr3KH6LDtowaKUEt7PpbGXqDrHT7Jth6vyLAa51j_VZf5cBffg5pBda816ZUiy6m73uas7rb02ntrjaIOiHGMgcdempWDnGl55tlBi4lnAsV2izqYiSiZAVfJRQnyxtGbK4qGWEFRu_0k1TGpHaoxlqAhdqRrl3MYHAJL93rgZxNBaOe_huI2xlJlFOgJ55mtUprKMSZN_opDuqeZPNNPJaZlCKjbYw30GUsTMjBta0rXy-Q834mmwvlTkfkekLzzpVgQRttVjYHAbxiaPWZ67tiLBhqkVcf5U7NgZAjOrS7-J2mpoR15VnZ7qhAGL6M9_rq38iQkvimuTvVt8ZUzjop-BZhKzuoph8gewr_kJ2d4CGcPlOzqa8GF70i5hbT0LxCwA==&p=3&fvj=1&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 5 :  Senior Data Analyst
# ==>Link: https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYlbfkN0A46AMWamQLJHyrSMqXKZLDjxYl1mrG9_PFP0VOb3INVDC8Hcu9b4LB72wepTSK0CSZckMpe7to0h94zKDSqzyd7TB8Y_oFfey34XuxE0PglXMyzF9BtWfRUpLkjcxE5nnpmYI0-TeLzcqwgmESfXLLSq8butTIwqgTwB0gSz7ngYohqMfxW7cQZ-rVPM4xjFPo2SB_SfpCi_904HX40jZA9Tle7ARFhMTexn1nbVAAqnX6cJath9skU2rGM8RoRYzZ-sEsvv_ROc7v1zN-fFkngtcouB8vvJflk0gNEZGJ6Tp800s7guP_EBHz6kfk2wveSpI3dtnQ5Dyl05vaEliJ2GqaZCp4mOJHhrGnDWBsqFqs_OAeaWTiI1y9vdHV_ZMOVIU2iiJiUhzyxoBcFSQgV9KF0RnoibU5_uH-ZAozilzYzYFk9iC9CM5mlbEUIfM=&p=4&fvj=1&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 6 :  Data Scientist
# ==>Link: https://www.indeed.ca/rc/clk?jk=c819cae5aae4c3bf&fccid=7c09b9795120f0d4&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 7 :  Data Scientist
# ==>Link: https://www.indeed.ca/rc/clk?jk=fa95daf5ee04790e&fccid=003656df63cede32&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 8 :  Data Scientist
# ==>Link: https://www.indeed.ca/rc/clk?jk=0a6813878acc5ab1&fccid=68463a22f867589a&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 9 :  Data Scientist
# ==>Link: https://www.indeed.ca/rc/clk?jk=0e65fb477b66886c&fccid=617690ce838507f3&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 10 :  LIFE Data Scientist (2020 Permanent – Toronto)
# ==>Link: https://www.indeed.ca/rc/clk?jk=e90bc12d5c4117ab&fccid=d4448c192a012f32&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 11 :  Data Scientist
# ==>Link: https://www.indeed.ca/company/MSi-Corp/jobs/Data-Scientist-3206f1f8714b7236?fccid=183e06e7def5a52c&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 12 :  Junior Data Scientist
# ==>Link: https://www.indeed.ca/rc/clk?jk=eb035b7aaaf2ec3e&fccid=14fcbdb0bd2b535f&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 13 :  Data Scientist
# ==>Link: https://www.indeed.ca/rc/clk?jk=eb07b6a8501f8faa&fccid=3002307a9e5b4706&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 14 :  Data Scientist
# ==>Link: https://www.indeed.ca/rc/clk?jk=668ca934e858032d&fccid=088981af222032de&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 15 :  Data Analyst
# ==>Link: https://www.indeed.ca/company/SunnyFuture-Career-Ltd./jobs/Data-Analyst-a1800d6984190c21?fccid=d1afcae81392e688&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 16 :  Data Scientist
# ==>Link: https://www.indeed.ca/rc/clk?jk=1ab872c530fe8515&fccid=ae6e110d9fec0378&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 17 :  Data Scientist, Big Data
# ==>Link: https://www.indeed.ca/rc/clk?jk=db4178733c09d159&fccid=d33243ac6c394a10&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 18 :  Machine Learning Engineer / Data Scientist
# ==>Link: https://www.indeed.ca/rc/clk?jk=e2322f987b7eeab1&fccid=80413c126d4e4312&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 19 :  Data Analyst
# ==>Link: https://www.indeed.ca/company/Postmedia-Network-Inc./jobs/Data-Analyst-272db504b727e384?fccid=88749d6501374165&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 20 :  Data Scientist / Engineer
# ==>Link: https://www.indeed.ca/rc/clk?jk=03dc820217100386&fccid=9402f6537fbfc5b0&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 21 :  Data Scientist
# ==>Link: https://www.indeed.ca/rc/clk?jk=94c4fe7af9489141&fccid=5434780ac3971e0d&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 22 :  Data Scientist
# ==>Link: https://www.indeed.ca/rc/clk?jk=23030c22963111ca&fccid=163ccc336a959b8b&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 23 :  Senior Data Scientist
# ==>Link: https://www.indeed.ca/rc/clk?jk=0339dc36d9d1343c&fccid=0376130dee20ed0f&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 24 :  Junior Data Scientist-AI & Data
# ==>Link: https://www.indeed.ca/rc/clk?jk=023cc044864c2c11&fccid=3a429036b3725efa&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 25 :  Data Scientist
# ==>Link: https://www.indeed.ca/rc/clk?jk=6fa8d6f34254db39&fccid=50f7dae6edfd9634&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 26 :  Data Scientist
# ==>Link: https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYlbfkN0BVjG0DVXkeYBH5Au4TYFNAdduwNOmfh0Qmzdp1i1PS2ydeJqoXPoRyIVn5da1eYihSeVxo-bzDfg4KtyFD_JKVSkOP70FUsH2bqzJBnv69zvojs2n3J9AeXHNdF8ojC3_-9uSJrYff9UdOYPUBGZu6_CYADRw2hOGQIX36S5KKpu80AYJKECLRMKe8LfjZCFLIz6yUFXpVGYwYWrdDZMsf40HvEwYnT24CbGnemS5ynJN3Fzy6zB_Y1odbKNaw6kYwpN0uqTLBzzrUJjRo_zQVe1wGgvOZryA5IkF0d_YwTJItkdtOTllz6GwaEDLy8z-ifI0fn3pQoxuVJc5M5ZjtNEOw6ZHfFmQGoQOTcYBxfSGu-zTdfpyoWhurOQ-gmU2Kowex-x8oFlxd24bweF15OVVmVze_yLVKvX-YI4Z0R1u-emeTvItGaFRh2lzTmXViNe11VUWS1egWOnspi0ha-f8g5058ZZQThl_P05GKSz-DMCy6j-6L20246lUl_G1SFovmVvOq4auGFtxrizSQuOrsNJ_1kMRPQ9C9y6vXdel6Sm7viQeI&p=25&fvj=0&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 27 :  Senior Data Scientist - Private Wealth
# ==>Link: https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYlbfkN0DPvDrY7fOi7IBjGen6Dx7RXxfTf3xqH9cPvuoqrlxtCEWGirnFmPeDqLmC0lmmv52T0OQy3uAgY4IMj43A9fADUrAakpKkjAiscrJrl6RaWxm5vlVTfU45ySXxPpObUjZLPoBJJshMgeq5lO-8um2MuSQRGAyfP5MVhjY4w1Hb3OZVdOkaU0HnnJEaPvJmaRLIdWCdU61Yyt1KxfGXJe_VDsTCSJzoWRXQzW1vnsikRtjRfvHH5DC0pb5zRRXaYg4ZUQdCB1KhaexWo9InjY5y7YuDBdKF_SQI-g9LWVDbkzzHOTDuYMx9d4TxFjMX8pedaUKPs5elALI-xwbmBsPf-nlQIj_WXEFX-TG0k3nFbM8fyB4hmd8A7RYjAOXuiWqJ5DyqJ3SXaFeECZIOiolALo-wA8AuDTAA93DDzKLgYFoNLZVEnqlaoeJDpJWSLrzVj_kYwHSoQ7O0c9l-SgrlQ9ghMdJscXnhIP0zLGweTLozFiCeEyqfRwGXhAzLUqbyhVNdExF2ZI_BWnLYBHagnL_lk0_QPKHlRAOH-PU2p7dBuZQ1wzy5MM8J0PwsUSuFehR6KDR6UA==&p=0&fvj=0&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 28 :  Sr. Data Engineer – Big Data
# ==>Link: https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYlbfkN0BlgGQq54RhTRbtNOtgf4q8ADJ3rNd1t7LC5bhoOEgeTJsUKQgehXcdqAKPOCuOlprjkGkz7OP3XVrPOTDcIgNPNUqAPKroP-1rENzkyHGcnm83XfjvXvpWPT0bTvC0DtrpTTWh3g4xecMLNVsO9eiYc8LO4QCh21KfASGoD0zZVRVNkEzLJAslkqLV6MVdAFd2Jy8mo_unAqy-dUGjkdNEhbz3grW2ALQsGXGc3SHQUO1Ey5q_SdKKq3DCJ4LGFUPmhBWM6rl5G02y8U2Um3IL4dT8uN6dSV9WbVveprCyQr4XjIec_vFgf3-5dV8wvaP2pfG-4vzlq9LJAbDfrufSX6Je9vhKHcPyVABRD19JQqDM_vxYTFPmyUemIs_B9RwfZJb-Mpu63tWYzObfmeR7Nm9j786UBw0Oq8P7raa9E6i5L2y87YySAV4FO6HENwPBH2nwVwCUdvwWJ1qH7sjJITzOj10JbnW8lxECjOsji4jZN_vemiVsryWWIE7XDnCrjbB6QDsNcIo52IVrgjMWcHKRHrYafkaPj3amkxTC_9Ow_gb8tKPS9VBpbk-cBlN9-zZHyNkP9M-s0eVrEBijYUvqNne-8JM-8q51iZIa_jZ-BBcvUWWI&p=1&fvj=0&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 29 :  Python Data Scientist - Research and Engineering
# ==>Link: https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYlbfkN0BFUzwZI7hB6sL3-1CSRuneG5TadXY2WMHKQsf1P6r6k45m7TN6EVbfDXe_axt3BS7b6n5egkEfAym44vnFG7hMQfQR9CMQJY7kizhXvr3KH6LDtowaKUEt7PpbGXqDrHT7Jth6vyLAa51j_VZf5cBffg5pBda816ZUiy6m73uas7rb02ntrjaI2xXzpzdca9npLplDcMC9_ncKzqJgLYwPmapv_ExVt7IA9zZYmDTu-hd-Yzqq5NuoUJSaZ4z_DVcIq0D-weF6PWvVmh9Hq7IQ6i7U-hKB043ToC4YK1GGaZG7BiMt36uWl3JxHFJLF_z_i_QeYAN2t9SvH_SFj3DvUDGTPoxuVzbgg2uMO1AR2NCPyKcWshw37NfVmoQkgo771TcI7yauKDSGxIycsqA2h-F_-2-pD3QMTlQwIPow62kPbSx_jaVIJZHDUU3kiWxOEjT2D6SC724Y2w6-D033L-hey-Kn53ITjhyNwKzzhg==&p=2&fvj=1&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 30 :  Senior Data Analyst
# ==>Link: https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYlbfkN0A46AMWamQLJHyrSMqXKZLDjxYl1mrG9_PFP0VOb3INVDC8Hcu9b4LB72wepTSK0CSZckMpe7to0h94zKDSqzyd7TB8Y_oFfey34XuxE0PglXMyzF9BtWfRUpLkjcxE5nnpmYI0-TeLzcqwgmESfXLLSq8butTIwqgTwB0gSz7ngQqaQQnqg6lztZaMAeBLj5BfdgVo0n_9-d1OoLK8z_OmCM7qUlVWo5DnOBjkgRN6sKKHr_0aAkzsazIazsuIyhebvYSLZlF4mq68lca6zu8-huHzzWfZfYIsJboFwuyYP8LgkRhqwysQlu2v2stfa4aUZMMCJ5NeHgAPnl0-eXetzuo5btRuVYQ_IMr5lK-9invkc8iWRWQnBWiANySSkF3X33_AF3AMsxTXR6xymiH8QXnlAMQPfxSTqFyw7zjAGXNrLlfW7GItDIZPt6sKLps=&p=3&fvj=1&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 31 :  Data Scientist/Time Series
# ==>Link: https://www.indeed.ca/rc/clk?jk=e97e7d4b249d30c2&fccid=ca1eb7a6353c159a&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 32 :  Senior Data Scientist - Product Sourcing
# ==>Link: https://www.indeed.ca/rc/clk?jk=5216f360808f8bf5&fccid=d5a5824be27ba831&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 33 :  Data Scientist
# ==>Link: https://www.indeed.ca/rc/clk?jk=68a8634fb53a4854&fccid=353eb997fc901045&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 34 :  Data Scientist
# ==>Link: https://www.indeed.ca/rc/clk?jk=9eba9802d5192217&fccid=0020889bfe35c4aa&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 35 :  Data Scientist (1 Year Contract)
# ==>Link: https://www.indeed.ca/rc/clk?jk=605c3999a3e99acb&fccid=237908de095b6446&vjs=3
# ---------------------------------------------------------------------------------
# ==>Job # 36 :  Data Scientist II
# ==>Link: https://www.indeed.ca/rc/clk?jk=f45bd342edba02e5&fccid=d7114f1cac8d0711&vjs=3

# %% [markdown]
# <div class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0DPvDrY7fOi7IBjGen6Dx7RXxfTf3xqH9cPvuoqrlxtCEWGirnFmPeDqLmC0lmmv52T0OQy3uAgY4IMj43A9fADUrAakpKkjAiscrJrl6RaWxm5vlVTfU45ySXxPpObUjZLPoBJJshMgeq5lO-8um2MuSQRGAyfP5MCFVkCHcAvSzUPkb39hIOjvRCKN_X_Mb2GRVmkZQ2V0AYOJJXPwN5QbGvBLug2jgfAWkfOlXnKRMp20C3CeTZ1uF3bjngUKZIe9FkyrgJ4H4AfZDC9PH8iS3VEhB00vQG4yg5NVGgbQnCB99xH6wUcCe3QK0RnDKyKT7OGpOm0iOFtPDmq78Mt3O2w_8kmN1Rib9dB0fKkb0G_lJ2B6HNAAdzjP7ttQT2FrOYH87xjjGfzZ2DXky8QmbA63uHSBz9fJcTraI1ZNoD4M28L10LbiIMigaZaod6rWK0Aub_u7NCLSJpmqr5H3ZI0MnoSBKwZzuofJbXSlcTFONKxXHBBiws_hoAsxcDCdSq1KumUndHguYEhmlqdGdsJHU4jis9-UfeMlOWEJj1FKKOE6pcWIQOudhAk7rGtmF1at6bEtA==&amp;p=0&amp;fvj=0&amp;vjs=3" id="sja0" onclick="setRefineByCookie([]); sjoc('sja0', 0); convCtr('SJ'); rclk(this,jobmap[0],true,0);" onmousedown="sjomd('sja0'); clk('sja0'); rclk(this,jobmap[0],0);" rel="noopener nofollow" target="_blank" title="Senior Data Scientist - Private Wealth">
# Senior <b>Data</b> <b>Scientist</b> - Private Wealth</a>
# </div>
